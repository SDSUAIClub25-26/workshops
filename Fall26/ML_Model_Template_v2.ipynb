# %% [markdown]
# **In this notebook, you can practice building and training your own machine learning model!**
#
# Basic machine learning workflow:
# 1. Load the data
# 2. Explore the data
# 3. Choose your features and target to predict
# 4. Train the model
# 5. Use the model to make predictions
# 6. Evaluate the model
# 7. Improve the model
#
# **Helpful Resource(s):**
# - [Three Components of Machine Learning Modeling](https://towardsdatascience.com/three-main-components-of-machine-learning-modeling-c9186658f7fe/)

# %% [markdown]
# # **Step 1: Import libraries**
#
# The primary libraries needed for ML are **pandas** for data manipulation, **scikit-learn** for machine learning tools, and **Matplotlib** and **Seaborn** for visualization.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Step 2: Load your dataset**
#
# Create a variable to hold the path to your dataset.
#
# Next, create a variable and use pandas to create a dataframe of your dataset.
#
# Now that we have our dataframe, we can use other functions to explore our dataset a bit further.
#
# Note: Remember, for the purposes of this workshop, we chose to use datasets that are already clean and ready for training. This is usually not the case in real applications, and you will have to perform pre-processing on the dataset in order to make it usable for model training.
#
# Datasets can be found [here](https://github.com/aiclub-sdsu/workshops/tree/main/Fall26/datasets).

# %%
# Create a variable holding the path to your dataset
path = "INSERT_PATH_HERE"

# Use the pandas library to read in your dataset and explore it
# Hint: Some needed functions might be:
# read_csv()
# head()
# describe()

# %%
# See the size of the dataset
data.shape

# %%
# See the column names
data.columns

# %% [markdown]
# # **Visualizing Data**
#
# At this point, we can create a graph of our data to better understand what we're working with. A scatterplot is useful for comparing two numerical variables and looking for relationships between them. We can do this using the Seaborn and Matplotlib libraries.
#
# At this stage, we are exploring the dataset itself. Later, after training the model, we will use different visualizations to evaluate its predictions.
#
# Try messing around with different features/targets and see if you can identify any relationships between the data.

# %%
# HINT: To make a functioning graph, you will need the following functions:
# scatterplot()
# title()
# xlabel()
# ylabel()
# show()

# %% [markdown]
# # **Step 3: Choose your target variable and features.**
#
# Your target (y) is what you want your model to be predicting.
#
# Your features (X) are the columns of the dataset that you want the model to take into account when predicting your target.

# %%
# Choose the target column
y =

# %%
# Choose feature columns
X =

# %% [markdown]
# # **Step 4: Split the data**
#
# Before we train our model, we need to split our data into two groups: **training data** and **testing data**.
#
# The training data is the data our model will learn from.
#
# The testing data is kept separate from the model during training. After training, we will ask the model to make predictions on this data to see how well it performs on houses it has never seen before.

# %%
# Before you run this, try to understand what the code is doing.
# What do the variable names mean?
# What do the arguments inside the function mean?

train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=1)

# %% [markdown]
# # **Step 5: Create and train the model**
#
# Now that we have set up our data, features, and target we want to predict, we can create our model and train it on the data.
#
# For the purposes of this workshop, try using some simple models. The model you use will depend on what type of data you are trying to predict: **regression** or **classification**. Here are some the models you can use.
#
# Regression:
#
# 1.   Linear Regression
# 2.   Decision Tree Regressor
# 3.   Random Forest Regressor
#
# Classification:
#
# 1.   Logistic Regression
# 2.   Decision Tree Classifier
# 3.   Random Forest Classifier
#
# Depending on which model you choose, there are different hyperparameters you can adjust. Search up what those hyperparameters are, what they mean, and experiment with different values.

# %%
# You can create any type of model you want, such as linear regression, random forest, etc.
model =

# %%
# Now, train the model with the fit() function, and make sure you are using the training data, not the testing data.

# %% [markdown]
# # **Step 6: Start making predictions**
#
# Now that the model is trained, it is ready to start making predictions on data that it hasn't seen (our testing data).

# %%
# The last function we used to train the model was called fit().
# What function name do you think we might need to make predictions?
predictions =

# Lists the first 10 predictions
predictions[:10]

# %% [markdown]
# # **Step 7: Evaluate the model's performance**
#
# We can create a new dataframe containing our target values vs. the predicted values to understand how accurate our model's predictions are.

# %%
# Look up how to create a dataframe with pandas, and take a look at it with the head() function we used previously.
results =

# %% [markdown]
# Another way to interpret the model's accuracy is by using **evaluation metrics**.
# The evaluation metric you choose depends on the type of problem you are solving.
#
# For **regression**, common metrics include MAE (Mean Absolute Error) and MSE (Mean Squared Error).
#
# For **classification**, common metrics include accuracy and precision.

# %%
# Choose a metric that makes sense for what your model is trying to predict.

# %% [markdown]
# We can also **visually** compare the predicted values against the target values to interpret how accurate our model is.
#
# The visualization you choose also depends on the type of problem you are solving.
#
# For **regression**, a scatter plot of actual vs. predicted values can show how close your predictions are to the real values.
#
# For **classification**, a confusion matrix can show which classes were predicted correctly and where the model made mistakes.

# %%
# Choose a visualization that best helps you understand your model's performance.

# %% [markdown]
# # **Step 8: Improve the model!**
#
# At this point, you have learned how to explore a dataset, pick out features and targets, train a model to make predictions, and use MAE to evaluate how accurate our model is.
#
# Now, go back to your data and experiment with adding/removing features to improve the model's accuracy. You can also experiment with choosing a different target to predict something else about the dataset!
